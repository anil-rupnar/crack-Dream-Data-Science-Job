# %% [markdown]
# ## Python Lambda, Map, Reduce, and Filter
#
# **Question 1**
#
# * **What does the lambda function in Python do?**
#
# **Options:**
#
# * creates an infinite loop
# * creates a named function
# * creates an anonymous function  (Answer)
# * None of the above
#
# **Explanation:** Lambda functions are small, one-line functions without a name, used for short-term tasks.
#
# **Question 2**
#
# * **What does the map function in Python do?**
#
# **Options:**
#
# * returns the first element in a list
# * applies a function to each element in a list and returns a list of the results  (Answer)
# * returns the last element in a list
# * None of the above
#
# **Explanation:** Map applies a function to each iterable element and returns a new iterable with the results.
#
# **Question 3**
#
# * **What does the reduce function in Python do?**
#
# **Options:**
#
# * applies a function to each element in a list and returns a list of the results
# * applies a function cumulatively to elements of an iterable, from left to right  (Answer)
# * returns the first element in a list
# * None of the above
#
# **Explanation:** Reduce applies a function cumulatively to iterable elements, producing a single value.
#
# **Question 4**
#
# * **What does the filter function in Python do?**
#
# **Options:**
#
# * returns a filtered list of elements that satisfy a condition  (Answer)
# * returns the first element in a list
# * returns the last element in a list
# * None of the above
#
# **Explanation:** Filter returns a new iterable with elements that meet a specified condition.
#
# **Question 5**
#
# * **What is the output of the following code?**
#
# ```python
# numbers = [1, 2, 3, 4, 5]
# squared_numbers = map(lambda x: x**2, numbers)
# print(list(squared_numbers))
#
# ```
# **Options:**
#
# * [0, 1, 4, 9, 16]
# * [2, 4, 6, 8, 10]
# * [1, 4, 9, 16, 25] (Answer)
# * None of the above
#
# **Explanation:** In this code, the map function is applied to each element in the list "numbers" using the lambda function, which squares each element. The result is a list of squared numbers, which is [1, 4, 9, 16, 25].
#
# **Question 6**
#
# * **What is the output of the following code?**
#
# ```python
# from functools import reduce
# numbers = [1, 2, 3, 4, 5]
# product = reduce(lambda x, y: x*y, numbers)
# print(product)
#
# ```
# **Options:**
#
# * 120 (Answer)
# * 30
# * 15
# * None of the above
#
# **Explanation:**  In this code, the reduce function is applied to the list "numbers" using the lambda function, which multiplies two elements. The result is the product of all elements in the list, which is 120.
#
# **Question 7**
#
# * **What is the output of the following code?**
#
# ```python
# numbers = [1, 2, 3, 4, 5]
# even_numbers = filter(lambda x: x%2 == 0, numbers)
# print(list(even_numbers))
#
# ```
# **Options:**
#
# * [2, 4]  (Answer)
# * [1, 3, 5]
# * [1, 2, 3, 4, 5]
# * None of the above
#
# **Explanation:**
#
# *  In this code, the filter function is applied to the list "numbers" using the lambda function, which checks if each element is even. The result is a filtered list of even numbers, which is [2, 4].
