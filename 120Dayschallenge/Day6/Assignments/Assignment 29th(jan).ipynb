# %%
#Q1.Who developed Python Programming Language?
'''Guido van Rossum developed Python programming language in the late 1980s.'''


#Q2.Which type of Programming does Python support?
'''Python supports multiple programming paradigms such as object-oriented, imperative, functional and procedural programming.'''

#Q3. Is Python case sensitive when dealing with identifiers?
'''Yes, Python is case sensitive when it comes to identifiers (variable names, function names, etc.).
   For example, a variable named "hello" is different from "Hello" or "HELLO". '''

#Q4. What is the correct extension of the Python file?
'''The correct extension for a Python file is .py. '''


# 5. Is Python code compiled or interpreted?
''' Python code is interpreted, not compiled. This means that the code is executed line by line, 
  rather than being translated into machine code before execution.
  
'''


#Q6. Name a few blocks of code used to define in Python language?
'''A few blocks of code used to define in Python language are:
   1.Functions, defined using the "def" keyword.
   2.Classes, defined using the "class" keyword.
   3.Conditional statements, such as "if" and "else".
   4.Loops, such as "for" and "while". 
   
'''



# Q7.State a character used to give single-line comments in Python?
''' In Python, the pound sign (#) is used to give single-line comments.'''



# Q8.Mention functions which can help us to find the version of python
'''  You can use the following functions to find the version of Python:
     sys.version
     sys.version_info
     platform.python_version()
'''

# Q9. Python supports the creation of anonymous functions at runtime, using a construct canstruct called 
'''In Python, anonymous functions at runtime can be created using a construct called "lambda". 
    The syntax for creating a lambda function is as follows:

    lambda arguments: expression
'''
    
-----------------------------------------------------------------------------
#Q10. What does pip stand for python?
''' PIP stands for "preferred installer program". 
    It is a package management system for installing and managing Python packages. 
    With PIP, you can easily install, upgrade, and manage packages for your Python projects.
    
'''


#Q11.Mention a few built-in functions in python?
'''
A few built-in functions in Python are:

1. print(): used to display output on the console.
2. len(): used to determine the length of a string, list, tuple, dictionary, etc.
3. type(): used to determine the data type of a variable.
4. int(): used to convert a string or a float to an integer.
5. str(): used to convert an integer or a float to a string.
6. sum(): used to calculate the sum of a list of numbers.
7. max(): used to find the maximum value in a list of numbers.
8. min(): used to find the minimum value in a list of numbers.
9. sorted(): used to sort a list of numbers.
10.range(): used to generate a range of numbers.

'''


#Q12 What is the maximum possible length of an identifier in Python?
'''the maximum possible length of an identifier is 79 characters in Python'''






# Q13.What are the benefits of using Python?
'''There are many benefits to using Python, including:

1.Easy to learn and use: 
  Python has a simple, easy-to-learn syntax that makes it a great first language for beginners.

2. Versatile: 
  Python can be used for a wide range of tasks, from web development to scientific computing, 
  data analysis, and machine learning.

3. Large community: 
  Python has a large and active community of developers, which makes it easy to find help and resources.

4. Plenty of libraries and modules: 
  Python has a vast collection of libraries and modules that provide pre-written code for various tasks. This makes it easier and faster to develop applications.

5. Dynamic typing: 
  Python supports dynamic typing, which means you can change the data type of a variable on the fly.

6. Interoperable with other languages: 
  Python can easily integrate with other programming languages, such as C/C++, Java, and more.

7. Good for prototyping:
  Python's fast development cycle and ease of use make it ideal for prototyping new ideas.

'''



#Q14.How is memory managed in Python?
'''In Python, memory management is handled automatically by the Python memory manager, which is part of the Python interpreter.
   The Python memory manager takes care of allocating and deallocating memory for the Python objects and data structures.
   Python uses a garbage collector to automatically detect and free up memory that is no longer in use by the program. 
   This helps to ensure that memory is used efficiently and that there are no memory leaks.
'''




#q15.How to install Python on Windows and set path variables?
''' 
To install Python on Windows and set the path variables, follow these steps:

1. Download the latest version of Python from the official website: https://www.python.org/downloads/

2.Run the Python installer and follow the on-screen instructions to complete the installation process.

3. After the installation is complete, open the Start menu and search for "Environment Variables".

4. Click on "Edit the system environment variables".

5. In the System Properties window, click on the "Environment Variables" button.

6. Under "System Variables", scroll down and find the "Path" variable.

7. Click on "Edit" and add the location of the Python executable to the Path variable. On most systems,
   this is located at "C:\PythonXX\Scripts", where "XX" is the version number of Python installed.

8 Close all windows and open a new command prompt to ensure that the changes take effect.

9. To check if Python is installed and the path variable is set correctly, 
   open a command prompt and type python. If the Python interpreter starts, 
   you have successfully installed Python and set the path variable.

'''



#Q16.indentation required in python?
'''Indentation is a key feature of the Python programming language and is used to define the block of code in Python.
   Indentation is required in Python to indicate the start and end of a code block and is used in place of curly braces ({}) 
   or keywords (such as "begin" and "end") used in other programming languages.
   In Python, a block of code is defined by a consistent indentation level.
   For example, the code inside a for loop, if statement, or function is indented to show that it is part of the block.
   
'''
