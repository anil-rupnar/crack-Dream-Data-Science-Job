# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a
# Out:
# 10

# %%
Anil = 20

# %%
Anil
# Out:
# 20

# %%
a+Anil
# Out:
# 30

# %%
type(a)
# Out:
# int

# %%
type(Anil)
# Out:
# int

# %%
b = 2.09

# %%
type(b)
# Out:
# float

# %%
c = 45.23345

# %%
type(c)
# Out:
# float

# %%
d = "Anil"

# %%
type(d)
# Out:
# str

# %%
e = 'this is my first tech class'

# %%
type(e)
# Out:
# str

# %%
n = True

# %%
type(n)
# Out:
# bool

# %%
m = False

# %%
type(m)
# Out:
# bool

# %%
n+m
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1684/3997983382.py in <module>
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
1 /0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1684/2116722390.py in <module>
# ----> 1 1 /0
#
# ZeroDivisionError: division by zero

# %%
#complex varible

# %%
Anil = 5 + 8j

# %%
type(Anil)
# Out:
# complex

# %%
Anil.real
# Out:
# 5.0

# %%
Anil.imag
# Out:
# 8.0

# %%
Anil
# Out:
# (5+8j)

# %%
print("my name is Anil")
# Out:
# my name is Anil

# %%
print(a)
# Out:
# 10

# %%
print(Anil)
# Out:
# (5+8j)

# %%
s = "AnilRupnar"

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'A'

# %%
s[2]
# Out:
# 'i'

# %%
s[3]
# Out:
# 'l'

# %%
s[-1]
# Out:
# 'r'

# %%
s[-8]
# Out:
# 'i'

# %%
s[0:3]
# Out:
# 'Ani'

# %%
s[0:2]
# Out:
# 'An'

# %%
s[0:4]
# Out:
# 'Anil'

# %%
s[0:8:2]
# Out:
# 'AiRp'

# %%
s[0:4:1]
# Out:
# 'Anil'

# %%
s[::2]
# Out:
# 'AiRpa'

# %%
s[0::2]
# Out:
# 'AiRpa'

# %%
s[2::2]
# Out:
# 'iRpa'

# %%
s[2::1]
# Out:
# 'ilRupnar'

# %%
s[::-1]
# Out:
# 'ranpuRlinA'

# %%
s
# Out:
# 'AnilRupnar'

# %%
s[2:7:-1]
# Out:
# ''

# %%
s[8:0]
# Out:
# ''

# %%
s[8::-1]
# Out:
# 'anpuRlinA'

# %%
s[-2 : -8 : -1]
# Out:
# 'anpuRl'

# %%
s[-2 : : -1]
# Out:
# 'anpuRlinA'

# %%
s[::-1]
# Out:
# 'ranpuRlinA'

# %%
s[::]
# Out:
# 'AnilRupnar'

# %%
s[:-90:]
# Out:
# ''

# %%
s[90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1684/3290760013.py in <module>
# ----> 1 s[90]
#
# IndexError: string index out of range

# %%
s[:-90000:-1]
# Out:
# 'ranpuRlinA'

# %%
c = 200

# %%
s1 = "this is my string class"

# %%
len(s1)
# Out:
# 23

# %%
s1.find('s')
# Out:
# 3

# %%
s1.find('i')
# Out:
# 2

# %%
s1.find("is")
# Out:
# 2

# %%
s
# Out:
# 'AnilRupnar'

# %%
#this is a code to find a charecterd of sub string in string 
s1.find("in")
# Out:
# 14

# %%
s1.count('s')
# Out:
# 5

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.count("st")
# Out:
# 1

# %%
s1.count('z')
# Out:
# 0

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s2 = 'THIS IS MY STRING CLASS'

# %%
s2
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s2.lower()
# Out:
# 'this is my string class'

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.title()
# Out:
# 'This Is My String Class'

# %%
s1.capitalize()
# Out:
# 'This is my string class'

# %%
s
# Out:
# 'AnilRupnar'

# %%
#string Don't concatinate with int

# %%
s + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1684/3893389454.py in <module>
# ----> 1 s + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s + " Rich"
# Out:
# 'AnilRupnar Rich'

# %%
s + '1'
# Out:
# 'AnilRupnar1'

# %%
s+ str(1)
# Out:
# 'AnilRupnar1'

# %%
s * 3
# Out:
# 'AnilRupnarAnilRupnarAnilRupnar'

# %%
'sudh' *4
# Out:
# 'sudhsudhsudhsudh'

# %%
"sudh" / 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1684/1860089750.py in <module>
# ----> 1 "sudh" / 4
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
"don't do copy and paste in my class"
# Out:
# "don't do copy and paste in my class"

# %%
'don"t do copy and paste in my class'
# Out:
# 'don"t do copy and paste in my class'

# %%
s3 = """This is my first class for programming
i have leant variable declaration , data type , string , int , boolean , complex number 
i have seen some example of string slicing and indexing 
i have gone though some of the string inbuilt function 
apart from that i am trying to practice in my system 
but some of us in our calss are not executing code and still they are answering which is bad """

# %%
s3
# Out:
# 'This is my first class for programming\ni have leant variable declaration , data type , string , int , boolean , complex number \ni have seen some example of string slicing and indexing \ni have gone though some of the string inbuilt function \napart from that i am trying to practice in my system \nbut some of us in our calss are not executing code and still they are answering which is bad '

# %%
s
# Out:
# 'AnilRupnar'

# %%
s[::-1]
# Out:
# 'ranpuRlinA'

# %%
s[-8::-1].upper()
# Out:
# 'INA'

# %%
s = "rohan"

# %%
s
# Out:
# 'rohan'

# %%
print(s)
# Out:
# rohan

# %%
s[-2::-1]
# Out:
# 'ahor'

# %%
s = "AnilRupnar"

# %%
s[-2::-1]
# Out:
# 'anpuRlinA'

# %%
s4= """Iam praharshitha
im in second year
i want to learn python"""

# %%
s4
# Out:
# 'Iam praharshitha\nim in second year\ni want to learn python'

# %%
s[:-8:-1]
# Out:
# 'ranpuRl'

# %%
s
# Out:
# 'AnilRupnar'

# %%
s * 3
# Out:
# 'AnilRupnarAnilRupnarAnilRupnar'

# %%
s = "AnilRupnar "

# %%
s*3
# Out:
# 'AnilRupnar AnilRupnar AnilRupnar '

# %%
a = 1

# %%
b = 3
c = 5

# %%
s
# Out:
# 'AnilRupnar '

# %%
s = 'myskill'

# %%
s[-2::-1]
# Out:
# 'liksym'

# %%
# jkfhsajasf
# fasdfhiasfhd
# ihasdufh
# iuhasdfias
# hoasdofasf
# hiuohasdofs
# hlohasfdsa

# %%
s = "pwskill"

# %%
s[2:3:1]
# Out:
# 's'

# %%
a = 10

# %%
a
# Out:
# 10
